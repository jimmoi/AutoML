# %%
from sklearn.datasets import load_wine

# %%
data = load_wine(as_frame=True)

# %%
data["frame"]
# Out:
#      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0      14.23        1.71  2.43               15.6      127.0           2.80
# 1      13.20        1.78  2.14               11.2      100.0           2.65
# 2      13.16        2.36  2.67               18.6      101.0           2.80
# 3      14.37        1.95  2.50               16.8      113.0           3.85
# 4      13.24        2.59  2.87               21.0      118.0           2.80
# ..       ...         ...   ...                ...        ...            ...
# 173    13.71        5.65  2.45               20.5       95.0           1.68
# 174    13.40        3.91  2.48               23.0      102.0           1.80
# 175    13.27        4.28  2.26               20.0      120.0           1.59
# 176    13.17        2.59  2.37               20.0      120.0           1.65
# 177    14.13        4.10  2.74               24.5       96.0           2.05
#
# ...

# %%
temp_df = data["data"]

# %%
temp_df["target"] = data["target"]

# %%
temp_df["target"] = temp_df["target"].map(lambda x : data["target_names"][x])

# %%
data["frame"].to_csv(r"C:\Hemoglobin\project\AutoML\dataset\regression\diabete.csv", index=False)

# %%
import pandas as pd

# %%
pd.read_csv("iris.csv")
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#         target
# 0       setosa
# ...

# %%
from sklearn.preprocessing import OneHotEncoder
import numpy as np

data = np.array([['Apple'], ['Banana'], ['Cherry']])

# Returns a sparse matrix (default)
enc_sparse = OneHotEncoder(sparse_output=True)
sparse_result = enc_sparse.fit_transform(data)

# Returns a standard numpy array
enc_dense = OneHotEncoder(sparse_output=False)
dense_result = enc_dense.fit_transform(data)

print(f"Sparse type: {type(sparse_result)}")
print(f"Dense type: {type(dense_result)}")
# Out:
# Sparse type: <class 'scipy.sparse._csr.csr_matrix'>
# Dense type: <class 'numpy.ndarray'>

# %%
# ------------------------
# 9. Feature selection / extraction
# ------------------------
if feature_method == "kbest":
    selector = SelectKBest(score_func=f_classif, k=k)
    X = selector.fit_transform(X, y)

elif feature_method == "variance":
    selector = VarianceThreshold(threshold=0.01)
    X = selector.fit_transform(X)

elif feature_method == "pca":
    pca = PCA(n_components=k)
    X = pca.fit_transform(X)

elif feature_method == "lda":
    lda = LinearDiscriminantAnalysis(n_components=min(k, len(set(y)) - 1))
    X = lda.fit_transform(X, y)

# %%
import numpy as np

test1 = np.array([0.1, 0.2, 0.2])
test2 = np.array(["0.1", "0.2", "0.2"])
test3 = np.array(["dog", "cat", "dog"])

# %%
np.unique(test1)
# Out:
# array([0.1, 0.2])

# %%
import numpy as np
import pandas as pd
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import cross_val_score 
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer

step = []

df = pd.read_csv("dataset\iris.csv")
X = df.iloc[:, :-1]
y = df.iloc[:, [-1]]

num_cols = X.select_dtypes(include=np.number).columns.tolist()
cat_cols = X.select_dtypes(exclude=np.number).columns.tolist()

num_steps = []
num_steps.append(("impute", SimpleImputer(strategy="mean")))
num_steps.append(("Scaler", StandardScaler()))
num_pipeline = Pipeline(num_steps)

cat_steps = []
cat_steps.append(("impute", SimpleImputer(strategy="most_frequent")))
cat_steps.append(("onehot", OneHotEncoder(handle_unknown="ignore")))
cat_pipeline = Pipeline(cat_steps)

preprocessor = ColumnTransformer(
        transformers=[
            ("num", num_pipeline, num_cols),
            ("cat", cat_pipeline, cat_cols)
        ])

step.append(("Preprocessor", preprocessor))
step.append(("Model", MLPClassifier()))
model = Pipeline(step)

scores = cross_val_score(model, X, y, cv=5, scoring="accuracy", n_jobs=-1)

# %%
scores
# Out:
# array([1.        , 0.96666667, 0.93333333, 0.93333333, 1.        ])

# %%
scores.mean()
# Out:
# np.float64(0.9666666666666668)

# %%
import numpy as np

def top_k_generate(n_column, n_choice):
    func2 = lambda x: np.ceil(n_column*(1e3**((x/x.max())-1)))
    test = np.arange(1,n_choice+1)
    test[1:] = func2(test)[:-1]
    return set(test.tolist())
top_k_generate(100, 10)
# Out:
# {1, 2, 4, 7, 13, 26, 51}

# %%
import pandas as pd

# %%
df = pd.read_csv(r"dataset\regression\taxi_trip_pricing.csv")
df
# Out:
#      Trip_Distance_km Time_of_Day Day_of_Week  Passenger_Count  \
# 0               19.35     Morning     Weekday              3.0
# 1               47.59   Afternoon     Weekday              1.0
# 2               36.87     Evening     Weekend              1.0
# 3               30.33     Evening     Weekday              4.0
# 4                 NaN     Evening     Weekday              3.0
# ..                ...         ...         ...              ...
# 995              5.49   Afternoon     Weekend              4.0
# 996             45.95       Night     Weekday              4.0
# 997              7.70     Morning     Weekday              3.0
# 998             47.56     Morning     Weekday              1.0
# 999             22.85     Morning     Weekend              3.0
#
#     Traffic_Conditions Weather  Base_Fare  Per_Km_Rate  Per_Minute_Rate  \
# 0                  Low   Clear       3.56         0.80             0.32
# ...

# %%
df.dropna(subset=["target"]).to_csv(r"dataset\regression\taxi_trip_pricing.csv", index=False)

# %%
df.drop(columns="id").to_csv(r"dataset\classification\breast-cancer.csv", index=False)

# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import Ridge
from sklearn.neural_network import MLPRegressor
from sklearn.model_selection import cross_val_score 
from sklearn.preprocessing import MinMaxScaler, OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer

step = []

df = pd.read_csv(r"dataset\regression\salary.csv")
X = df.iloc[:, :-1]
y = df.iloc[:, [-1]]

num_cols = X.select_dtypes(include=np.number).columns.tolist()
cat_cols = X.select_dtypes(exclude=np.number).columns.tolist()

num_steps = []
num_steps.append(("impute", SimpleImputer(strategy="mean")))
num_steps.append(("Scaler", MinMaxScaler()))
num_pipeline = Pipeline(num_steps)

cat_steps = []
cat_steps.append(("impute", SimpleImputer(strategy="most_frequent")))
cat_steps.append(("onehot", OneHotEncoder(handle_unknown="ignore")))
cat_pipeline = Pipeline(cat_steps)

preprocessor = ColumnTransformer(
        transformers=[
            ("num", num_pipeline, num_cols),
            ("cat", cat_pipeline, cat_cols)
        ])

step.append(("Preprocessor", preprocessor))
step.append(("Model", MLPRegressor()))
model = Pipeline(step)

scores = cross_val_score(model, X, y, cv=5, scoring="neg_mean_squared_error", n_jobs=-1)

# %%
import numpy as np
import pandas as pd
from sklearn.neural_network import MLPRegressor
from sklearn.model_selection import cross_val_score 
from sklearn.preprocessing import MinMaxScaler, OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.datasets import fetch_california_housing

# 1. Load Dataset
data = fetch_california_housing()
X = pd.DataFrame(data.data, columns=data.feature_names)
y = data.target

# Add a fake categorical column so your cat_pipeline gets used
X['location_type'] = np.random.choice(['Urban', 'Suburban', 'Rural'], size=len(X))

# 2. Identify Columns
num_cols = X.select_dtypes(include=np.number).columns.tolist()
cat_cols = X.select_dtypes(exclude=np.number).columns.tolist()

# 3. Build Pipelines
num_pipeline = Pipeline([
    ("impute", SimpleImputer(strategy="mean")),
    ("Scaler", MinMaxScaler())
])

cat_pipeline = Pipeline([
    ("impute", SimpleImputer(strategy="most_frequent")),
    ("onehot", OneHotEncoder(handle_unknown="ignore"))
])

preprocessor = ColumnTransformer(transformers=[
    ("num", num_pipeline, num_cols),
    ("cat", cat_pipeline, cat_cols)
])

# 4. Final Model Pipeline
# Note: Added max_iter=500 because Neural Nets often need more iterations to converge
full_pipeline = Pipeline([
    ("Preprocessor", preprocessor),
    ("Model", MLPRegressor(max_iter=500, hidden_layer_sizes=(50, 50), random_state=42))
])

# 5. Cross Validation
# Using n_jobs=-1 uses all CPU cores
scores = cross_val_score(full_pipeline, X, y, cv=5, scoring="neg_mean_squared_error", n_jobs=-1)

mse_scores = -scores
print(f"Average MSE: {mse_scores.mean():.4f}")
# Out:
# Average MSE: 0.4732

# %%
from sklearn.datasets import fetch_california_housing

# 1. Load Dataset
data = fetch_california_housing(as_frame=True)

# %%
data = data["frame"]

# %%
data.rename(columns={"MedHouseVal":"target"},inplace=True)
data.to_csv(r"dataset\regression\california_housing.csv", index=False)

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split

# Load the diabetes dataset
diabetes_X, diabetes_y = datasets.load_diabetes(return_X_y=True)

# For this example, let's use just one feature (BMI) to make it easy to visualize
# BMI is at index 2
diabetes_X_single = diabetes_X[:, np.newaxis, 2]

# %%
# Split the data into training/testing sets
X_train, X_test, y_train, y_test = train_test_split(
    diabetes_X_single, diabetes_y, test_size=0.2, random_state=42
)

# Create linear regression object
regr = linear_model.LinearRegression()

# Train the model
regr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Make predictions using the testing set
diabetes_y_pred = regr.predict(X_test)

# Model performance
print(f"Coefficients: {regr.coef_[0]:.2f}")
print(f"Mean squared error: {mean_squared_error(y_test, diabetes_y_pred):.2f}")
print(f"Coefficient of determination (R^2): {r2_score(y_test, diabetes_y_pred):.2f}")
# Out:
# Coefficients: 998.58
# Mean squared error: 4061.83
# Coefficient of determination (R^2): 0.23

# %%
plt.scatter(X_test, y_test, color="black", label="Actual Data")
plt.plot(X_test, diabetes_y_pred, color="blue", linewidth=3, label="Regression Line")
plt.xlabel("Body Mass Index (Scaled)")
plt.ylabel("Disease Progression")
plt.legend()
plt.show()
